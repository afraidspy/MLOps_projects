# %% [markdown]
# # Probar Modelos con PyCaret (TEMPLATE DATAPATH - Prof. Inofuente)

# %% [markdown]
# # Paso 1: Cargamos Pycaret y un Dataset

# %%
# !pip install pycaret
# Out:
# Requirement already satisfied: pycaret in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (9.6.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (8.1.7)
# Requirement already satisfied: tqdm>=4.62.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (4.67.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (3.1.6)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (2.0.5)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (0.14.0)
# Requirement already satisfied: category-encoders>=2.4.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (4.6.0)
# Requirement already satisfied: numba>=0.55.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (0.62.1)
# Requirement already satisfied: requests>=2.27.1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (2.32.5)
# Requirement already satisfied: psutil>=5.9.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (7.1.0)
# Requirement already satisfied: markupsafe>=2.0.1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (3.0.3)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (8.7.0)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (3.1.1)
# Requirement already satisfied: deprecation>=2.1.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (3.6.0)
# Requirement already satisfied: matplotlib<3.8.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (6.3.1)
# Requirement already satisfied: kaleido>=0.2.1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (1.1.0)
# Requirement already satisfied: schemdraw==0.15 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: statsmodels>=0.12.1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (0.14.5)
# Requirement already satisfied: sktime==0.26.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: wurlitzer in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pycaret) (3.1.1)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from sktime==0.26.0->pycaret) (25.0)
# Requirement already satisfied: scikit-base<0.8.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret) (1.4.9)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from scikit-learn>1.4.0->pycaret) (3.6.0)
# Requirement already satisfied: patsy>=0.5.1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from category-encoders>=2.4.0->pycaret) (1.0.1)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from importlib-metadata>=4.12.0->pycaret) (3.23.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (2.19.2)
# Requirement already satisfied: stack_data in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (4.15.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.14)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.15)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.5)
# Requirement already satisfied: choreographer>=1.0.10 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from kaleido>=0.2.1->pycaret) (1.1.2)
# Requirement already satisfied: logistro>=1.0.8 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from kaleido>=0.2.1->pycaret) (2.0.0)
# Requirement already satisfied: orjson>=3.10.15 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from kaleido>=0.2.1->pycaret) (3.11.3)
# Requirement already satisfied: pytest-timeout>=2.4.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from kaleido>=0.2.1->pycaret) (2.4.0)
# Requirement already satisfied: simplejson>=3.19.3 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from choreographer>=1.0.10->kaleido>=0.2.1->pycaret) (3.20.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from nbformat>=4.2.0->pycaret) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from nbformat>=4.2.0->pycaret) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from nbformat>=4.2.0->pycaret) (5.8.1)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.5.0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from numba>=0.55.0->pycaret) (0.45.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from plotly>=5.14.0->pycaret) (2.8.0)
# Requirement already satisfied: dash>=2.11.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.2.0)
# Requirement already satisfied: tsdownsample>=0.1.3 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.4.1)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.3)
# Requirement already satisfied: retrying in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.4.2)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (80.9.0)
# Requirement already satisfied: blinker>=1.9.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.3.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pmdarima>=2.0.4->pycaret) (3.1.4)
# Requirement already satisfied: urllib3 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pmdarima>=2.0.4->pycaret) (2.5.0)
# Requirement already satisfied: pytest>=7.0.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (8.4.2)
# Requirement already satisfied: iniconfig>=1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (1.6.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from requests>=2.27.1->pycaret) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from requests>=2.27.1->pycaret) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from requests>=2.27.1->pycaret) (2025.10.5)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from stack_data->ipython>=5.5.0->pycaret) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from stack_data->ipython>=5.5.0->pycaret) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from stack_data->ipython>=5.5.0->pycaret) (0.2.3)

# %%
# !pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (7.0.1)
# Requirement already satisfied: appnope>=0.1.2 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipykernel) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipykernel) (9.6.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil>=5.7 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipykernel) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (4.15.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/anaconda3/envs/Datapath-MLOps13/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)

# %%
import pycaret
pycaret.__version__
# Out:
# '3.3.2'

# %%
from pycaret.datasets import get_data
Datos_traffic = get_data(dataset = 'diamond') #Aquí cambias el Dataset
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171

# %% [markdown]
# # Paso 2: Importar las Regresiones de Pycaret y Crear el Objeto

# %%
from pycaret.regression import *

# %%
# import RegressionExperiment and init the class
from pycaret.regression import RegressionExperiment
ExperimentoRegresion = RegressionExperiment() #Instanciamos la clase

# %% [markdown]
# # Paso 3: Configurar el Experimento u Objeto

# %%
# init setup on exp
ExperimentoRegresion.setup(Datos_traffic, target = 'Price', session_id = 123) #Target = 'Sale Price'
                                          #Coloco la etiqueta de mi Target, en este caso el Volumen del Tráfico
# Out:
# <style type="text/css">
# #T_f65ab_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f65ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f65ab_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f65ab_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f65ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f65ab_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f65ab_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f65ab_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f65ab_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f65ab_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f65ab_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f65ab_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f65ab_row3_col1" class="data row3 col1" >(6000, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f65ab_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f65ab_row4_col1" class="data row4 col1" >(6000, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f65ab_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f65ab_row5_col1" class="data row5 col1" >(4200, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f65ab_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f65ab_row6_col1" class="data row6 col1" >(1800, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f65ab_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f65ab_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f65ab_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_f65ab_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f65ab_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_f65ab_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f65ab_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_f65ab_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f65ab_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_f65ab_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f65ab_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_f65ab_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f65ab_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_f65ab_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f65ab_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_f65ab_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f65ab_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_f65ab_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f65ab_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_f65ab_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f65ab_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_f65ab_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f65ab_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_f65ab_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f65ab_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_f65ab_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f65ab_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_f65ab_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f65ab_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f65ab_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_f65ab_row21_col1" class="data row21 col1" >3a5d</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Usamos la VALIDACIÓN CRUZADA KFold, cuya técnica divide el conjunto de datos en K partes (o folds). En cada iteración del proceso, se utiliza uno de los folds como conjunto de prueba y los otros K-1 como conjunto de entrenamiento. Esto se repite K veces.

# %% [markdown]
# # Paso 4: Entrenamos y Comparamos los Modelos

# %%
#Comparamos los Modelos usando POO
MejorModelo = ExperimentoRegresion.compare_models()
# Out:
# <style type="text/css">
# #T_1c566 th {
#   text-align: left;
# }
# #T_1c566_row0_col0, #T_1c566_row0_col5, #T_1c566_row0_col6, #T_1c566_row1_col0, #T_1c566_row1_col1, #T_1c566_row1_col2, #T_1c566_row1_col3, #T_1c566_row1_col4, #T_1c566_row1_col5, #T_1c566_row1_col6, #T_1c566_row2_col0, #T_1c566_row2_col1, #T_1c566_row2_col2, #T_1c566_row2_col3, #T_1c566_row2_col4, #T_1c566_row3_col0, #T_1c566_row3_col1, #T_1c566_row3_col2, #T_1c566_row3_col3, #T_1c566_row3_col4, #T_1c566_row3_col5, #T_1c566_row3_col6, #T_1c566_row4_col0, #T_1c566_row4_col1, #T_1c566_row4_col2, #T_1c566_row4_col3, #T_1c566_row4_col4, #T_1c566_row4_col5, #T_1c566_row4_col6, #T_1c566_row5_col0, #T_1c566_row5_col1, #T_1
models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# gbr             Gradient Boosting Regressor
# mlp                           MLP Regressor
# lightgbm    Light Gradient Boosting Machine
# dummy                       Dummy Regressor
#
#                                                   Reference  Turbo
# ID
# lr              sklearn.linear_model._base.LinearRegression   True
# lasso        sklearn.linear_model._coordinate_descent.Lasso   True
# ridge                     sklearn.linear_model._ridge.Ridge   True
# en        sklearn.linear_model._coordinate_descent.Elast...   True
# lar                  sklearn.linear_model._least_angle.Lars   True
# llar            sklearn.linear_model._least_angle.LassoLars   True
# omp       sklearn.linear_model._omp.OrthogonalMatchingPu...   True
# br                sklearn.linear_model._bayes.BayesianRidge   True
# ard               sklearn.linear_model._bayes.ARDRegression  False
# par       sklearn.linear_model._passive_aggressive.Passi...   True
# ransac         sklearn.linear_model._ransac.RANSACRegressor  False
# tr        sklearn.linear_model._theil_sen.TheilSenRegressor  False
# huber            sklearn.linear_model._huber.HuberRegressor   True
# kr                         sklearn.kernel_ridge.KernelRidge  False
# svm                                sklearn.svm._classes.SVR  False
# knn       sklearn.neighbors._regression.KNeighborsRegressor   True
# dt              sklearn.tree._classes.DecisionTreeRegressor   True
# rf           sklearn.ensemble._forest.RandomForestRegressor   True
# et             sklearn.ensemble._forest.ExtraTreesRegressor   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostRegr...   True
# gbr          sklearn.ensemble._gb.GradientBoostingRegressor   True
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# lightgbm                     lightgbm.sklearn.LGBMRegressor   True
# dummy                          sklearn.dummy.DummyRegressor   True

# %%
compare_tree_models = ExperimentoRegresion.compare_models(include = ['lr', 'lasso', 'ridge', 'en', 'lar'])
# Out:
# <style type="text/css">
# #T_ed3ed th {
#   text-align: left;
# }
# #T_ed3ed_row0_col0, #T_ed3ed_row0_col1, #T_ed3ed_row0_col5, #T_ed3ed_row0_col6, #T_ed3ed_row1_col0, #T_ed3ed_row1_col2, #T_ed3ed_row1_col3, #T_ed3ed_row1_col4, #T_ed3ed_row1_col5, #T_ed3ed_row2_col0, #T_ed3ed_row2_col1, #T_ed3ed_row2_col2, #T_ed3ed_row2_col3, #T_ed3ed_row2_col4, #T_ed3ed_row2_col5, #T_ed3ed_row2_col6, #T_ed3ed_row3_col0, #T_ed3ed_row3_col1, #T_ed3ed_row3_col2, #T_ed3ed_row3_col3, #T_ed3ed_row3_col4, #T_ed3ed_row3_col6, #T_ed3ed_row4_col0, #T_ed3ed_row4_col1, #T_ed3ed_row4_col2, #T_ed3ed_row4_col3, #T_ed3ed_row4_col4, #T_ed3ed_row4_col5, #T_ed3ed_row4_col6 {
#   text-align: left;
# }
# #T_ed3ed_row0_col2, #T_ed3ed_row0_col3, #T_ed3ed_row0_col4, #T_ed3ed_row1_col1, #T_ed3ed_row1_col6, #T_ed3ed_row3_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ed3ed_row0_col7, #T_ed3ed_row1_col7, #T_ed3ed_row2_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ed3ed_row3_col7, #T_ed3ed_row4_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ed3ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed3ed_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ed3ed_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ed3ed_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ed3ed_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ed3ed_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ed3ed_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ed3ed_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ed3ed_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed3ed_level0_row0" class="row_heading level0 row0" >ridge</th>
#       <td id="T_ed3ed_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_ed3ed_row0_col1" class="data row0 col1" >2491.2859</td>
#       <td id="T_ed3ed_row0_col2" class="data row0 col2" >14957594.1466</td>
#       <td id="T_ed3ed_row0_col3" class="data row0 col3" >3840.8633</td>
#       <td id="T_ed3ed_row0_col4" class="data row0 col4" >0.8568</td>
#       <td id="T_ed3ed_row0_col5" class="data row0 col5" >0.6470</td>
#       <td id="T_ed3ed_row0_col6" class="data row0 col6" >0.2966</td>
#       <td id="T_ed3ed_row0_col7" class="data row0 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_ed3ed_level0_row1" class="row_heading level0 row1" >lasso</th>
#       <td id="T_ed3ed_row1_col0" class="data row1 col0" >Lasso Regression</td>
#       <td id="T_ed3ed_row1_col1" class="data row1 col1" >2490.7990</td>
#       <td id="T_ed3ed_row1_col2" class="data row1 col2" >14993880.8447</td>
#       <td id="T_ed3ed_row1_col3" class="data row1 col3" >3845.5124</td>
#       <td id="T_ed3ed_row1_col4" class="data row1 col4" >0.8565</td>
#       <td id="T_ed3ed_row1_col5" class="data row1 col5" >0.6525</td>
#       <td id="T_ed3ed_row1_col6" class="data row1 col6" >0.2961</td>
#       <td id="T_ed3ed_row1_col7" class="data row1 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_ed3ed_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_ed3ed_row2_col0" class="data row2 col0" >Linear Regression</td>
#       <td id="T_ed3ed_row2_col1" class="data row2 col1" >2548.1062</td>
#       <td id="T_ed3ed_row2_col2" class="data row2 col2" >15276396.6757</td>
#       <td id="T_ed3ed_row2_col3" class="data row2 col3" >3885.3286</td>
#       <td id="T_ed3ed_row2_col4" class="data row2 col4" >0.8534</td>
#       <td id="T_ed3ed_row2_col5" class="data row2 col5" >0.6547</td>
#       <td id="T_ed3ed_row2_col6" class="data row2 col6" >0.3063</td>
#       <td id="T_ed3ed_row2_col7" class="data row2 col7" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_ed3ed_level0_row3" class="row_heading level0 row3" >en</th>
#       <td id="T_ed3ed_row3_col0" class="data row3 col0" >Elastic Net</td>
#       <td id="T_ed3ed_row3_col1" class="data row3 col1" >5094.9781</td>
#       <td id="T_ed3ed_row3_col2" class="data row3 col2" >58154229.7819</td>
#       <td id="T_ed3ed_row3_col3" class="data row3 col3" >7593.6540</td>
#       <td id="T_ed3ed_row3_col4" class="data row3 col4" >0.4407</td>
#       <td id="T_ed3ed_row3_col5" class="data row3 col5" >0.5372</td>
#       <td id="T_ed3ed_row3_col6" class="data row3 col6" >0.5835</td>
#       <td id="T_ed3ed_row3_col7" class="data row3 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_ed3ed_level0_row4" class="row_heading level0 row4" >lar</th>
#       <td id="T_ed3ed_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#       <td id="T_ed3ed_row4_col1" class="data row4 col1" >11008514.7096</td>
#       <td id="T_ed3ed_row4_col2" class="data row4 col2" >8699051444826363.0000</td>
#       <td id="T_ed3ed_row4_col3" class="data row4 col3" >29676386.8034</td>
#       <td id="T_ed3ed_row4_col4" class="data row4 col4" >-77650923.2616</td>
#       <td id="T_ed3ed_row4_col5" class="data row4 col5" >2.6784</td>
#       <td id="T_ed3ed_row4_col6" class="data row4 col6" >1535.9929</td>
#       <td id="T_ed3ed_row4_col7" class="data row4 col7" >0.0100</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### *Resolver*
# #### 2. ¿Por qué escogiste estos 7 modelos en la lista de include?. Si deseas puedes ayudarte del ordenamiento

# %% [markdown]
# # Paso 4 (Opcional):Ordenamiento de los mejores modelos respecto de una métrica

# %%
Mejores_Modelos_TOP3_MAE = ExperimentoRegresion.compare_models(sort = 'R2', n_select = 3)
# Out:
# <style type="text/css">
# #T_034f4 th {
#   text-align: left;
# }
# #T_034f4_row0_col0, #T_034f4_row0_col5, #T_034f4_row0_col6, #T_034f4_row1_col0, #T_034f4_row1_col1, #T_034f4_row1_col2, #T_034f4_row1_col3, #T_034f4_row1_col4, #T_034f4_row1_col5, #T_034f4_row1_col6, #T_034f4_row2_col0, #T_034f4_row2_col1, #T_034f4_row2_col2, #T_034f4_row2_col3, #T_034f4_row2_col4, #T_034f4_row3_col0, #T_034f4_row3_col1, #T_034f4_row3_col2, #T_034f4_row3_col3, #T_034f4_row3_col4, #T_034f4_row3_col5, #T_034f4_row3_col6, #T_034f4_row4_col0, #T_034f4_row4_col1, #T_034f4_row4_col2, #T_034f4_row4_col3, #T_034f4_row4_col4, #T_034f4_row4_col5, #T_034f4_row4_col6, #T_034f4_row5_col0, #T_034f4_row5_col1, #T_034f4_row5_col2, #T_034f4_row5_col3, #T_034f4_row5_col4, #T_034f4_row5_col5, #T_034f4_row5_col6, #T_034f4_row6_col0, #T_034f4_row6_col1, #T_034f4_row6_col2, #T_034f4_row6_col3, #T_034f4_row6_col4, #T_034f4_row6_col5, #T_034f4_row6_col6, #T_034f4_row7_col0, #T_034f4_row7_col1, #T_034f4_row7_col2, #T_034f4_row7_col3, #T_034f4_row7_col4, #T_034f4_row7_col5, #T_034f4_row7_col6, #T_034f4_row8_col0, #T_034f4_row8_col1, #T_034f4_row8_col2, #T_034f4_row8_col3, #T_034f4_row8_col4, #T_034f4_row8_col5, #T_034f4_row8_col6, #T_034f4_row9_col0, #T_034f4_row9_col1, #T_034f4_row9_col2, #T_034f4_row9_col3, #T_034f4_row9_col4, #T_034f4_row9_col5, #T_034f4_row9_col6, #T_034f4_row10_col0, #T_034f4_row10_col1, #T_034f4_row10_col2, #T_034f4_row10_col3, #T_034f4_row10_col4, #T_034f4_row10_col5, #T_034f4_row10_col6, #T_034f4_row11_col0, #T_034f4_row11_col1, #T_034f4_row11_col2, #T_034f4_row11_col3, #T_034f4_row11_col4, #T_034f4_row11_col5, #T_034f4_row11_col6, #T_034f4_row12_col0, #T_034f4_row12_col1, #T_034f4_row12_col2, #T_034f4_row12_col3, #T_034f4_row12_col4, #T_034f4_row12_col5, #T_034f4_row12_col6, #T_034f4_row13_col0, #T_034f4_row13_col1, #T_034f4_row13_col2, #T_034f4_row13_col3, #T_034f4_row13_col4, #T_034f4_row13_col5, #T_034f4_row13_col6, #T_034f4_row14_col0, #T_034f4_row14_col1, #T_034f4_row14_col2, #T_034f4_row14_col3, #T_034f4_row14_col4, #T_034f4_row14_col5, #T_034f4_row14_col6, #T_034f4_row15_col0, #T_034f4_row15_col1, #T_034f4_row15_col2, #T_034f4_row15_col3, #T_034f4_row15_col4, #T_034f4_row15_col5, #T_034f4_row15_col6, #T_034f4_row16_col0, #T_034f4_row16_col1, #T_034f4_row16_col2, #T_034f4_row16_col3, #T_034f4_row16_col4, #T_034f4_row16_col5, #T_034f4_row16_col6, #T_034f4_row17_col0, #T_034f4_row17_col1, #T_034f4_row17_col2, #T_034f4_row17_col3, #T_034f4_row17_col4, #T_034f4_row17_col5, #T_034f4_row17_col6 {
#   text-align: left;
# }
# #T_034f4_row0_col1, #T_034f4_row0_col2, #T_034f4_row0_col3, #T_034f4_row0_col4, #T_034f4_row2_col5, #T_034f4_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_034f4_row0_col7, #T_034f4_row1_col7, #T_034f4_row2_col7, #T_034f4_row3_col7, #T_034f4_row4_col7, #T_034f4_row6_col7, #T_034f4_row7_col7, #T_034f4_row8_col7, #T_034f4_row9_col7, #T_034f4_row10_col7, #T_034f4_row11_col7, #T_034f4_row12_col7, #T_034f4_row13_col7, #T_034f4_row14_col7, #T_034f4_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_034f4_row5_col7, #T_034f4_row15_col7, #T_034f4_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_034f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_034f4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_034f4_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_034f4_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_034f4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_034f4_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_034f4_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_034f4_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_034f4_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_034f4_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_034f4_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_034f4_row0_col1" class="data row0 col1" >719.6871</td>
#       <td id="T_034f4_row0_col2" class="data row0 col2" >2033874.0284</td>
#       <td id="T_034f4_row0_col3" class="data row0 col3" >1390.8879</td>
#       <td id="T_034f4_row0_col4" class="data row0 col4" >0.9809</td>
#       <td id="T_034f4_row0_col5" class="data row0 col5" >0.0786</td>
#       <td id="T_034f4_row0_col6" class="data row0 col6" >0.0585</td>
#       <td id="T_034f4_row0_col7" class="data row0 col7" >0.1020</td>
#     </tr>
#     <tr>
#       <th id="T_034f4_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_034f4_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_034f4_row1_col1" class="data row1 col1" >725.2336</td>
#       <td id="T_034f4_row1_col2" class="data row1 col2" >2336507.8192</td>
#       <td id="T_034f4_row1_col3" class="data row1 col3" >1491.6157</td>
#       <td id="T_034f4_row1_col4" class="data row1 col4" >0.9781</td>
#       <td id="T_034f4_row1_col5" class="data row1 col5" >0.0785</td>
#       <td id="T_034f4_row1_col6" class="data row1 col6" >0.0577</td>
#       <td id="T_034f4_row1_col7" class="data row1 col7" >0.0890</td>
#     </tr>
#     <tr>
#       <th id="T_034f4_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_034f4_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_034f4_row2_col1" class="data row2 col1" >721.5692</td>
#       <td id="T_034f4_row2_col2" class="data row2 col2" >2747712.1060</td>
#       <td id="T_034f4_row2_col3" class="data row2 col3" >1593.0198</td>
#       <td id="T_034f4_row2_col4" class="data row2 col4" >0.9748</td>
#       <td id="T_034f4_row2_col5" class="data row2 col5" >0.0750</td>
#       <td id="T_034f4_row2_col6" class="data row2 col6" >0.0551</td>
#       <td id="T_034f4_row2_col7" class="data row2 col7" >0.3840</td>
#     </tr>
#     <tr>
#       <th id="T_034f4_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_034f4_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_034f4_row3_col1" class="data row3 col1" >870.4619</td>
#       <td id="T_034f4_row3_col2" class="data row3 col2" >2677900.4116</td>
#       <td id="T_034f4_row3_col3" class="data row3 col3" >1616.3756</td>
#       <td id="T_034f4_row3_col4" class="data row3 col4" >0.9744</td>
#       <td id="T_034f4_row3_col5" class="data row3 col5" >0.0990</td>
#       <td id="T_034f4_row3_col6" class="data row3 col6" >0.0750</td>
#       <td id="T_034f4_row3_col7" class="data row3 col7" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_034f4_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_034f4_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_034f4_row4_col1" class="data row4 col1" >919.7628</td>
#       <td id="T_034f4_row4_col2" class="data row4 col2" >3495425.3910</td>
#       <td id="T_034f4_row4_col3" class="data row4 col3" >1821.5832</td>
#       <td id="T_034f4_row4_col4" class="data row4 col4" >0.9664</td>
#       <td id="T_034f4_row4_col5" class="data row4 col5" >0.1025</td>
#       <td id="T_034f4_row4_col6" class="data row4 col6" >0.0744</td>
#       <td id="T_034f4_row4_col7" class="data row4 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_034f4_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_034f4_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_034f4_row5_col1" class="data row5 col1" >2491.2859</td>
#       <td id="T_034f4_row5_col2" class="data row5 col2" >14957594.1466</td>
#       <td id="T_034f4_row5_col3" class="data row5 col3" >3840.8633</td>
#       <td id="T_034f4_row5_col4" class="data row5 col4" >0.8568</td>
#       <td id="T_034f4_row5_col5" class="data row5 col5" >0.6470</td>
#       <td id="T_034f4_row5_col6" class="data row5 col6" >0.2966</td>
#       <td id="T_034f4_row5_col7" class="data row5

# %% [markdown]
# # Paso 5: Tuneamos los hypermarámetros del Mejor Modelo

# %%
# Ahora seleccionas uno de esos modelos para tunearlo
MejorModelo = Mejores_Modelos_TOP3_MAE[0]  # Selecciona el mejor de los tres

# %%
print(MejorModelo)
# Out:
# ExtraTreesRegressor(n_jobs=-1, random_state=123)

# %%
MejorModelo_Tuneado = ExperimentoRegresion.tune_model(estimator=MejorModelo)
# Out:
# <style type="text/css">
# #T_812b3_row10_col0, #T_812b3_row10_col1, #T_812b3_row10_col2, #T_812b3_row10_col3, #T_812b3_row10_col4, #T_812b3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_812b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_812b3_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_812b3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_812b3_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_812b3_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_812b3_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_812b3_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_812b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_812b3_row0_col0" class="data row0 col0" >930.4948</td>
#       <td id="T_812b3_row0_col1" class="data row0 col1" >4826662.5855</td>
#       <td id="T_812b3_row0_col2" class="data row0 col2" >2196.9667</td>
#       <td id="T_812b3_row0_col3" class="data row0 col3" >0.9565</td>
#       <td id="T_812b3_row0_col4" class="data row0 col4" >0.1001</td>
#       <td id="T_812b3_row0_col5" class="data row0 col5" >0.0764</td>
#     </tr>
#     <tr>
#       <th id="T_812b3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T
>0.0770</td>
#     </tr>
#     <tr>
#       <th id="T_812b3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_812b3_row9_col0" class="data row9 col0" >844.5161</td>
#       <td id="T_812b3_row9_col1" class="data row9 col1" >2290525.8284</td>
#       <td id="T_812b3_row9_col2" class="data row9 col2" >1513.4483</td>
#       <td id="T_812b3_row9_col3" class="data row9 col3" >0.9742</td>
#       <td id="T_812b3_row9_col4" class="data row9 col4" >0.0903</td>
#       <td id="T_812b3_row9_col5" class="data row9 col5" >0.0706</td>
#     </tr>
#     <tr>
#       <th id="T_812b3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_812b3_row10_col0" class="data row10 col0" >900.4611</td>
#       <td id="T_812b3_row10_col1" class="data row10 col1" >3395320.1270</td>
#       <td id="T_812b3_row10_col2" class="data row10 col2" >1797.4998</td>
#       <td id="T_812b3_row10_col3" class="data row10 col3" >0.9683</td>
#       <td id="T_812b3_row10_col4" class="data row10 col4" >0.0967</td>
#       <td id="T_812b3_row10_col5" class="data row10 col5" >0.0735</td>
#     </tr>
#     <tr>
#       <th id="T_812b3_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_812b3_row11_col0" class="data row11 col0" >74.1109</td>
#       <td id="T_812b3_row11_col1" class="data row11 col1" >1583824.1457</td>
#       <td id="T_812b3_row11_col2" class="data row11 col2" >405.3573</td>
#       <td id="T_812b3_row11_col3" class="data row11 col3" >0.0108</td>
#       <td id="T_812b3_row11_col4" class="data row11 col4" >0.0052</td>
#       <td id="T_812b3_row11_col5" class="data row11 col5" >0.0038</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# ### *Resolver*
# #### 3. ¿El mejor modelo tuneado ha tenido mejores valores de salida respecto a las métrica que el mejor modelo sin tunear?. Si tuvo o no, justifica tu respuesta.

# %% [markdown]
# # Paso 6: Finalizar Modelo

# %%
Modelo_Final = ExperimentoRegresion.finalize_model(estimator = MejorModelo_Tuneado) #Escoger el MejorModelo o MejorModelo_Tuneado dependiendo de tu respuesta de arriba.

# %%
Modelo_Final
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['Carat Weight'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=['Cut', 'Color', 'Clarity',
#                                              'Polish', 'Symmetry', 'Report'],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('ordinal_encoding',
#                  TransformerWrapper(include=['Rep...
#                 ('onehot_encoding',
#                  TransformerWrapper(include=['Cut', 'Color', 'Clarity',
#                                              'Polish', 'Symmetry'],
#                                     transformer=OneHotEncoder(cols=['Cut',
#                                                                     'Color',
#                                                                     'Clarity',
#                                                                     'Polish',
#                                                                     'Symmetry'],
#                                                               handle_missing='return_nan',
#                                                               use_cat_names=True))),
#                 ('clean_column_names',
#                  TransformerWrapper(transformer=CleanColumnNames())),
#                 ('actual_estimator',
#                  ExtraTreesRegressor(n_jobs=-1, random_state=123))])

# %% [markdown]
# # Paso 7: Guardar Modelo

# %%
ExperimentoRegresion.save_model(model = Modelo_Final, model_name = './Models/Modelo_Final_1')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Carat Weight'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['Cut', 'Color', 'Clarity',
#                                               'Polish', 'Symmetry', 'Report'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('ordinal_encoding',
#                   TransformerWrapper(include=['Rep...
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['Cut', 'Color', 'Clarity',
#                                               'Polish', 'Symmetry'],
#                                      transformer=OneHotEncoder(cols=['Cut',
#                                                                      'Color',
#                                                                      'Clarity',
#                                                                      'Polish',
#                                                                      'Symmetry'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('clean_column_names',
#                   TransformerWrapper(transformer=CleanColumnNames())),
#                  ('actual_estimator',
#                   ExtraTreesRegressor(n_jobs=-1, random_state=123))]),
#  './Models/Modelo_Final_1.pkl')

# %%
import joblib
joblib.dump(MejorModelo_Tuneado, 'modelo_entrenado_solo.pkl')
# Out:
# ['modelo_entrenado_solo.pkl']

# %% [markdown]
# # Paso 8: Cargar Modelo (Hasta aquí entra la Tarea)

# %%
Modelo_Cargado_desde_Disco = ExperimentoRegresion.load_model('./Models/Modelo_Final_1')
# Out:
# Transformation Pipeline and Model Successfully Loaded
